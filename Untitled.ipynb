# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# 1. Establish the connection string to your local PostgreSQL database
# Format: 'postgresql://username:password@localhost:port/database_name'
# Replace 'YOUR_PASSWORD' with the master password you set in pgAdmin!
db_uri = 'postgresql://postgres:Bsrma153997@153@localhost:5432/postgres'
engine = create_engine(db_uri)

print("Connecting to the database engine...")

try:
    # 2. Extract data directly out of the test table you created earlier
    query = "SELECT * FROM test_users;"
    df = pd.read_sql(query, con=engine)
    
    print("\n--- Success! Data Extracted Into Pandas DataFrame ---")
    print(df)
    
    # 3. Create a quick status plot tracking our users
    plt.figure(figsize=(6, 4))
    plt.bar(df['name'], df['id'], color='skyblue')
    plt.title('My First Data Pipeline Status')
    plt.ylabel('ID Value')
    
    # 4. Save the plot asset directly into your portfolio repository folder
    # Adjust this path if your path folder is located elsewhere
    output_path = r'C:\Users\HP\Desktop\data_analytics_portfolio\pipeline_plot.png'
    plt.savefig(output_path, bbox_inches='tight')
    plt.close()
    
    print(f"\nSuccess! Performance graph exported directly to: {output_path}")

except Exception as e:
    print("\nPipeline failed. Double check your pgAdmin password or server port.")
    print(e)
# Out:
# Connecting to the database engine...
#
# Pipeline failed. Double check your pgAdmin password or server port.
# (psycopg2.OperationalError) could not translate host name "153@localhost" to address: Non-recoverable failure in name resolution
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import urllib.parse  # 💡 Added this tool to fix special characters

# 1. Type your password safely inside quotes below
raw_password = "Bsrma153997@153" 
safe_password = urllib.parse.quote_plus(raw_password)

# 2. Establish the connection using the safely encoded password
db_uri = f'postgresql://postgres:{safe_password}@localhost:5432/postgres'
engine = create_engine(db_uri)

print("Connecting to the database engine...")

try:
    # 3. Extract data directly out of the test table you created earlier
    query = "SELECT * FROM test_users;"
    df = pd.read_sql(query, con=engine)
    
    print("\n--- Success! Data Extracted Into Pandas DataFrame ---")
    print(df)
    
    # 4. Create a quick status plot tracking our database entries
    plt.figure(figsize=(6, 4))
    plt.bar(df['name'], df['id'], color='skyblue')
    plt.title('My First Data Pipeline Status')
    plt.ylabel('ID Value')
    
    # 5. Save the plot asset directly into your portfolio repository folder
    output_path = r'C:\Users\HP\Desktop\data_analytics_portfolio\pipeline_plot.png'
    plt.savefig(output_path, bbox_inches='tight')
    plt.close()
    
    print(f"\nSuccess! Performance graph exported directly to: {output_path}")

except Exception as e:
    print("\nPipeline failed. Double check your pgAdmin password or server port.")
    print(e)
# Out:
# Connecting to the database engine...
#
# --- Success! Data Extracted Into Pandas DataFrame ---
#    id                     name
# 0   1  My First Company Server
#
# Success! Performance graph exported directly to: C:\Users\HP\Desktop\data_analytics_portfolio\pipeline_plot.png
